# %%
pip install pandas Faker
# Out:
# /usr/lib/python3/dist-packages/secretstorage/dhcrypto.py:15: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /usr/lib/python3/dist-packages/secretstorage/util.py:19: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Exercise 1.
#
# What is `overloading` and `overriding` ? Can you `overload` in Python?
#
# Create a class `Puppy` which inherits from the `Dog` class. Try overriding the `bark` method - a puppy should bark half as much.
#
# Example:
#
# doggie = Dog(2) <br>
# pupper = Puppy(2)
#
# doggie.bark() <br>
#     <i>Woof! Woof!</i>
#
# pupper.bark() <br>
#     <i>Woof!</i>

# %%
class Dog:
    def __init__(self, size):
        self.size = size
    def bark(self):
        for i in range(self.size):
            print("Woof!")

# %%
# Write your code here

# %% [markdown]
# # Exercise 2.
#
# Here is the dataframe `df` for Invoices table. <br>
#
# Please group all Invoices from each contry and sum up their value (`Total` column). <br>
#
# Example result: <br>
#
# <table>
#     <tr>
#     <th>Country</th>
#     <th> Total </th>
#     </tr>
#     <tr>
#         <td>Germany</td>
#         <td>101.13 </td>
#     </tr>
#     <tr>
#         <td>Poland</td>
#         <td>22.16 </td>
#     </tr>
#     <tr>
#         <td>Spain</td>
#         <td>55.23 </td>
#     </tr>
#     <tr>
#         <td>Canada</td>
#         <td>78.99 </td>
#     </tr>
#     <tr>
#         <td>...</td>
#         <td>...</td>
#     </tr>
# </table>

# %%
# Run this cell. The code takes the data from database and saves it to df DataFrame.
import sqlite3 as lite
import pandas as pd

con = lite.connect('chinook.db')
cur = con.cursor()
sql = "SELECT * FROM Invoices"
cur.execute(sql)
df = pd.DataFrame(data=cur.fetchall(), columns=[col[0] for col in cur.description])
df
# Out:
#      InvoiceId  CustomerId          InvoiceDate  \
# 0            1           2  2009-01-01 00:00:00
# 1            2           4  2009-01-02 00:00:00
# 2            3           8  2009-01-03 00:00:00
# 3            4          14  2009-01-06 00:00:00
# 4            5          23  2009-01-11 00:00:00
# ..         ...         ...                  ...
# 407        408          25  2013-12-05 00:00:00
# 408        409          29  2013-12-06 00:00:00
# 409        410          35  2013-12-09 00:00:00
# 410        411          44  2013-12-14 00:00:00
# 411        412          58  2013-12-22 00:00:00
#
#                                BillingAddress BillingCity BillingState  \
# 0                     Theodor-Heuss-Straße 34   Stuttgart         None
# 1                            Ullevålsveien 14        Oslo         None
# 2                             Grétrystraat 63    Brussels         None
# 3                              8210 111 ST NW    Edmonton           AB
# ...

# %%
# Write your code here

# %% [markdown]
# # Exercise 3.
#
# Using `Faker` library, write a simple event generator. We want to know the time of the event, type, who did it... and other useful information :)
#
# Documentation:
# https://faker.readthedocs.io/en/master/

# %%
# Write your code here
